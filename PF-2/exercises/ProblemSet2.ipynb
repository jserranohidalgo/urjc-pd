// %% [markdown]
// # Declarative Programming @ URJC
// # Functional programming
// ## Problem Set 2: Algebraic data types

// %% [markdown]
// Auxiliary definitions:

// %%
trait Isomorphic[A, B]{
    
    def from(a: A): B
    
    def to(b: B): A
    
    // equality 
    
    def equalA(a1: A, a2: A): Boolean = 
        a1 == a2
    
    def equalB(b1: B, b2: B): Boolean =
        b1 == b2
    
    // Bijection laws
    
    def law1(a: A): Boolean = 
        equalA(to(from(a)), a)
    
    def law2(b: B): Boolean = 
        equalB(from(to(b)), b)
}
// Out:
// defined trait Isomorphic

// %% [markdown]
// # Exercise 0

// %% [markdown]
// $$
// \begin{array}{rcl}
// Either[X,Either[Y,Z]] & \cong & Either[Either[X,Y],Z] \\
// \end{array}
// $$

// %% [markdown]
// $$
// \begin{array}{rcl}
// x+(y+z) & = & (x+y)+z \\
// \end{array}
// $$

// %%
/*type X = Boolean
type Y = Unit
type Z = Char

val l: Either[X, Either[Y, Z]] = Left(??? : Boolean)
val l2: Either[X, Either[Y, Z]] = Right(??? : Either[Unit, Char])

val r: Either[Either[X, Y], Z] = Left(??? : Either[Boolean, Unit])
val r2: Either[Either[X, Y], Z] = Right(??? : Char)
*/
class Iso[X, Y, Z] extends Isomorphic[
    Either[X, Either[Y, Z]], 
    Either[Either[X, Y], Z]
    ]{
    
    def from(a: Either[X,Either[Y,Z]]): Either[Either[X,Y],Z] = 
        ??? : Either[Either[X,Y],Z]
    
    // Constructor L: Either
    def from1(a: Either[X,Either[Y,Z]]): Either[Either[X,Y],Z] = 
        Left(??? : Either[X, Y]) : Either[Either[X,Y],Z]
    
    // Constructor L: Either
    def from2(a: Either[X,Either[Y,Z]]): Either[Either[X,Y],Z] = 
        // Left(??? : A) : Either[A, B]
        Left(Left(??? : X) : Either[X, Y]) : Either[Either[X,Y],Z]
    
    // Observer: Either
    def from3(a: Either[X,Either[Y,Z]]): Either[Either[X,Y],Z] = 
        a match {
            case Left(x: X) => 
                Left(Left(??? : X) : Either[X, Y]) : Either[Either[X,Y],Z]
            case Right(e: Either[Y, Z]) => 
                Left(Left(??? : X) : Either[X, Y]) : Either[Either[X,Y],Z]
        }
    
    // Observer: Var
    def from4(a: Either[X,Either[Y,Z]]): Either[Either[X,Y],Z] = 
        a match {
            case Left(x: X) => 
                Left(Left(x : X) : Either[X, Y]) : Either[Either[X,Y],Z]
            case Right(e: Either[Y, Z]) => 
                Left(Left(??? : X) : Either[X, Y]) : Either[Either[X,Y],Z]
        }
    
    
    // Constructor R: Either
    def from5(a: Either[X,Either[Y,Z]]): Either[Either[X,Y],Z] = 
        a match {
            case Left(x: X) => 
                Left(Left(x : X) : Either[X, Y]) : Either[Either[X,Y],Z]
            case Right(e: Either[Y, Z]) => 
                Left(Right(??? : Y) : Either[X, Y]) : Either[Either[X,Y],Z]
        }
    
    // Observer: Either
    def from6(a: Either[X,Either[Y,Z]]): Either[Either[X,Y],Z] = 
        a match {
            case Left(x: X) => 
                Left(Left(x : X) : Either[X, Y]) : Either[Either[X,Y],Z]
            case Right(e: Either[Y, Z]) => 
                e match {
                    case Left(y: Y) => 
                        Left(Right(??? : Y) : Either[X, Y]) : Either[Either[X,Y],Z]
                    case Right(z: Z) => 
                        Left(Right(??? : Y) : Either[X, Y]) : Either[Either[X,Y],Z]
                }
        }
    
    // Observer: Var
    def from7(a: Either[X,Either[Y,Z]]): Either[Either[X,Y],Z] = 
        a match {
            case Left(x: X) => 
                Left(Left(x : X) : Either[X, Y]) : Either[Either[X,Y],Z]
            case Right(e: Either[Y, Z]) => 
                e match {
                    case Left(y: Y) => 
                        Left(Right(y : Y) : Either[X, Y]) : Either[Either[X,Y],Z]
                    case Right(z: Z) => 
                        Left(Right(??? : Y) : Either[X, Y]) : Either[Either[X,Y],Z]
                }
        }
    
    // Constructor R: Either
    def from8(a: Either[X,Either[Y,Z]]): Either[Either[X,Y],Z] = 
        a match {
            case Left(x: X) => 
                Left(Left(x : X) : Either[X, Y]) : Either[Either[X,Y],Z]
            case Right(e: Either[Y, Z]) => 
                e match {
                    case Left(y: Y) => 
                        Left(Right(y : Y) : Either[X, Y]) : Either[Either[X,Y],Z]
                    case Right(z: Z) => 
                        Right(??? : Z) : Either[Either[X,Y],Z]
                }
        }
    
    // Observer: Var
    def from9(a: Either[X,Either[Y,Z]]): Either[Either[X,Y],Z] = 
        a match {
            case Left(x: X) => 
                Left(Left(x : X) : Either[X, Y]) : Either[Either[X,Y],Z]
            case Right(e: Either[Y, Z]) => 
                e match {
                    case Left(y: Y) => 
                        Left(Right(y : Y) : Either[X, Y]) : Either[Either[X,Y],Z]
                    case Right(z: Z) => 
                        Right(z : Z) : Either[Either[X,Y],Z]
                }
        }
    
    def to(b: Either[Either[X,Y],Z]): Either[X,Either[Y,Z]] = 
        ??? 

}
// Out:
// defined class Iso

// %% [markdown]
// ## Exercise 1

// %% [markdown]
// ### Part a)

// %% [markdown]
// Prove that the isomorphism $1+1 \cong Boolean$ holds by implementing the following bijections:

// %%
object Iso extends Isomorphic[Either[Unit, Unit], Boolean]{
 
    def from(a: Either[Unit, Unit]): Boolean = 
        ???
    
    def to(a: Boolean): Either[Unit, Unit] = 
        ???
    
}

// %% [markdown]
// Check that they are indeed mutual inverses, i.e. that for all $a: Boolean$, `toBoolean(fromBoolean(a))==a`, and that for all $a: Either[Unit, Unit]$, `fromBoolean(toBoolean(a))==a`.

// %% [markdown]
// ### Part b)

// %% [markdown]
// Show that we can redefine `Option[A]` using `Either[A,Unit]`:

// %%
class Iso[A] extends Isomorphic[Option[A], Either[A, Unit]]{
    
    def from(o: Option[A]): Either[A, Unit] = 
        ???

    def to(e: Either[A, Unit]): Option[A] = 
        ???
}

// %% [markdown]
// Check that these functions are mutual inverses. For that, fix $A$ to particular types (e.g. `Boolean`, `Int`, etc.), and test the equivalences `from(to(e)) == e` and `to(from(o)) == o` for some values $o$ and $e$.

// %% [markdown]
// ## Exercise 2

// %% [markdown]
// How many functions are there of type `1+1+1 => Boolean`? Identify all of them as alternative implementations of the following signature:

// %%
def f1(e: Either[Unit, Either[Unit, Unit]]): Boolean = 
    ???

// %% [markdown]
// Idem, as alternative lambda expressions:

// %%
lazy val f1: Either[Unit, Either[Unit, Unit]] => Boolean = 
    ???

// %% [markdown]
// ## Exercise 3

// %% [markdown]
// How many different implementations are there of the following function signature? Recall that two implementations will be considered different if the corresponding mathematical functions are different. Write all of them.

// %%
def f1(b: Boolean): Either[Unit, Either[Unit, Unit]] = 
    ???

// %% [markdown]
// ## Exercise 4

// %% [markdown]
// Show that the following law holds for exponent types: $(Z^Y)^X = Z^{Y*X}$, for all types $X$, $Y$ and $Z$.

// %%
class Iso[X, Y, Z] extends Isomorphic[X => (Y => Z), ((Y, X)) => Z]{
    
    // Constructor => (lambda expression)
    def from0(f: X => (Y => Z)): ((Y, X)) => Z = 
        (a: (Y, X)) => ??? : Z
        
    // Available variables: {f, a}
    // Observer => (function application)
    def from1(f: X => (Y => Z)): ((Y, X)) => Z = 
        (a: (Y, X)) => {
            val fyz: Y => Z = f(??? : X)
            ??? : Z
        }
        
    // Available variables: {f, a, fyz}
    // Observer 2 (,)
    def from2(f: X => (Y => Z)): ((Y, X)) => Z = 
        (a: (Y, X)) => {
            val fyz: Y => Z = f(a._2 : X)
            ??? : Z
        }

    // Available variables: {f, a, fyz}
    // Observer 2 (,)
    def from3(f: X => (Y => Z)): ((Y, X)) => Z = 
        (a: (Y, X)) => {
            val fyz: Y => Z = f(a._2 : X)
            fyz(??? : Y) : Z
        }
        
    // Available variables: {f, a, fyz}
    // Observer 1 (,)
    def from(f: X => (Y => Z)): ((Y, X)) => Z = 
        (a: (Y, X)) => {
            val fyz: Y => Z = f(a._2 : X)
            fyz(a._1 : Y) : Z
        }
        
    // curry
    def to0(f: ((Y, X)) => Z): X => (Y => Z) = 
        ??? : (X => (Y => Z))
    
    // Constructor => 
    def to1(f: ((Y, X)) => Z): X => (Y => Z) = 
        // ((a: A) => ??? : B): A => B
        ((a: X) => ??? : Y => Z) : (X => (Y => Z))

    // Constructor => 
    def to2(f: ((Y, X)) => Z): X => (Y => Z) = 
        // ((a: A) => ??? : B): A => B
        (a: X) => ((a: Y) => ??? : Z) : (Y => Z)

    // Available: {f, a, b}
    // Constructor (,) 
    def to3(f: ((Y, X)) => Z): X => (Y => Z) = 
        // (??? : A, ??? : B) : (A, B)
        (a: X) => ((b: Y) => f((??? : Y, ??? : X) : (Y, X)) : Z)

    // Available: {f, a, b}
    // Observer: Var
    def to(f: ((Y, X)) => Z): X => (Y => Z) = 
        // (??? : A, ??? : B) : (A, B)
        (a: X) => ((b: Y) => f((b : Y, a : X) : (Y, X)) : Z)
}
// Out:
// defined class Iso

// %%
class Iso[X, Y, Z] extends Isomorphic[X => (Y => Z), ((Y, X)) => Z]{
    
    def from(f: X => (Y => Z)): ((Y, X)) => Z = 
        a => f(a._2)(a._1)
        
    def to(f: ((Y, X)) => Z): X => (Y => Z) = 
        a => b => f((b, a))
}
// Out:
// defined class Iso

// %%
object Iso1 extends Iso[Boolean, Unit, Unit]
// Out:
// defined object Iso1

// %%
// |Unit => Unit|^|Boolean| = (|Unit|^|Unit|)^|Boolean| = (1^1)^2 = 1 ^ 2 = 1
val f: Boolean => (Unit => Unit) =
    (b: Boolean) => (u: Unit) => () : Unit

Iso1.to(Iso1.from(f)) // ==  f
// Out:
// f: Boolean => Unit => Unit = ammonite.$sess.cmd23$Helper$$Lambda$2306/629733541@2aec3a2c
// res23_1: Boolean = false

// %%
// |Unit => Unit|^|Boolean| = (|Unit|^|Unit|)^|Boolean| = (1^1)^2 = 1 ^ 2 = 1
object Iso1 extends Iso[Unit, Boolean, Boolean]

val f: Unit => (Boolean => Boolean) =
    (u: Unit) => (b: Boolean) => if (b) true else false

val f1: Unit => (Boolean => Boolean) = 
    Iso1.to(Iso1.from(f))

val g: Unit => (Boolean => Boolean) = 
    u => b => if (!b) true else false

val g1: Unit => (Boolean => Boolean) = 
    Iso1.to(Iso1.from(g))


// f == f1?

f(())(false) == f1(())(false)
f(())(true) == f1(())(true)

// g == f1?

g(())(false) == g1(())(false)
g(())(true) == g1(())(true)
// Out:
// defined object Iso1
// f: Unit => Boolean => Boolean = ammonite.$sess.cmd27$Helper$$$Lambda$2372/136905267@7b902aca
// f1: Unit => Boolean => Boolean = ammonite.$sess.cmd17$Helper$Iso$$Lambda$2302/1384272127@c87d011
// g: Unit => Boolean => Boolean = ammonite.$sess.cmd27$Helper$$$Lambda$2373/1862934869@46782a29
// g1: Unit => Boolean => Boolean = ammonite.$sess.cmd17$Helper$Iso$$Lambda$2302/1384272127@3bfc33e
// res27_5: Boolean = true
// res27_6: Boolean = true
// res27_7: Boolean = true
// res27_8: Boolean = true

// %% [markdown]
// Implement function equality for the following signatures and check that both functions, `curry` and `uncurry`, are inverses of each other for two sample functions $ex1$ and $ex2$:

// %%
def ex1: Boolean => Boolean => Boolean = 
    ???

def ex2: (Boolean, Boolean) => Boolean = 
    ???

// %% [markdown]
// Accordingly, we need to override the equality functions:

// %%
object Iso extends Iso[Boolean, Boolean, Boolean]{
    
    override def equalA(f1: Boolean => Boolean => Boolean, 
               f2: Boolean => Boolean => Boolean): Boolean = 
        ???
    
    override def equalB(f1: (Boolean, Boolean) => Boolean, 
               f2: (Boolean, Boolean) => Boolean): Boolean = 
        ???
}

// %% [markdown]
// Now, check that curry and uncurry are inverses of each other for sample
// functions `ex1` and `ex2`:

// %% [markdown]
// ## Exercise 5

// %% [markdown]
// Shows that the following law holds for exponent types: $(Y*Z)^X \cong Y^X*Z^X$, for all types $X$, $Y$ and $Z$.

// %%
// extends trait Isomorphic

// %% [markdown]
// Fix the type parameters to particular types $A$, $B$ and $C$, implement equality for the corresponding signatures and check that both functions, `from[A, B, C]` and `to[A, B, C]`, are inverses of each other given two sample functions of your choice.

// %%
// give two sample functions

// %%
// override equality functions

// %%
// test laws
